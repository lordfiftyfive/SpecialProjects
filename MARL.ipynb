# %%
#marllib requires python 3.8 to work properly

from marllib import marl

# prepare env
#env = marl.make_env(environment_name="mpe", map_name="simple_spread")

# initialize algorithm with appointed hyper-parameters
#mappo = marl.algos.mappo(hyperparam_source="mpe")

# build agent model based on env + algorithms + user preference
#model = marl.build_model(env, mappo, {"core_arch": "mlp", "encode_layer": "128-256"})

# start training
#mappo.fit(env, model, stop={'episode_reward_mean': 2000, 'timesteps_total': 10000000}, local_mode=False, num_gpus=0,num_workers=1, share_policy='group', checkpoint_freq=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 #marllib requires python 3.8 to work properly
# ----> 3 from marllib import marl
#       5 # prepare env
#       6 #env = marl.make_env(environment_name="mpe", map_name="simple_spread")
#       7
#    (...)
#      14 # start training
#      15 #mappo.fit(env, model, stop={'episode_reward_mean': 2000, 'timesteps_total': 10000000}, local_mode=False, num_gpus=0,num_workers=1, share_policy='group', checkpoint_freq=50)
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/marllib/marl/__init__.py:25
#       1 # MIT License
#       2
#       3 # Copyright (c) 2023 Replicable-MARL
#    (...)
#      20 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      21 # SOFTWARE.
#      23 from marllib.marl.common import dict_update, get_model_config, check_algo_type, \
#      24     recursive_dict_update
# ---> 25 from marllib.marl.algos import run_il, run_vd, run_cc
#      26 from marllib.marl.algos.scripts import POlICY_REGISTRY
#      27 from marllib.envs.base_env import ENV_REGISTRY
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/marllib/marl/algos/__init__.py:23
#       1 # MIT License
#       2
#       3 # Copyright (c) 2023 Replicable-MARL
#    (...)
#      20 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      21 # SOFTWARE.
# ---> 23 from .run_cc import run_cc
#      24 from .run_vd import run_vd
#      25 from .run_il import run_il
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/marllib/marl/algos/run_cc.py:23
#       1 # MIT License
#       2
#       3 # Copyright (c) 2023 Replicable-MARL
#    (...)
#      20 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      21 # SOFTWARE.
# ---> 23 import ray
#      24 from ray import tune
#      25 from ray.rllib.utils.framework import try_import_tf, try_import_torch
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/ray/__init__.py:91
#      88 __commit__ = "92599d9127e228fe8d0a2d94ca75754ec21c4ae4"
#      89 __version__ = "1.9.0"
# ---> 91 import ray._raylet  # noqa: E402
#      93 from ray._raylet import (  # noqa: E402
#      94     ActorClassID, ActorID, NodeID, Config as _Config, JobID, WorkerID,
#      95     FunctionID, ObjectID, ObjectRef, TaskID, UniqueID, Language,
#      96     PlacementGroupID)
#      98 _config = _Config()
#
# File python/ray/_raylet.pyx:104, in init ray._raylet()
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/ray/exceptions.py:5
#       2 from traceback import format_exception
#       4 import ray.cloudpickle as pickle
# ----> 5 from ray.core.generated.common_pb2 import RayException, Language, PYTHON
#       6 from ray.core.generated.common_pb2 import Address
#       7 import ray.ray_constants as ray_constants
#
# File ~/miniconda3/envs/Marl/lib/python3.8/site-packages/ray/core/generated/common_pb2.py:22
#      10 # @@protoc_insertion_point(imports)
#      12 _sym_db = _symbol_database.Default()
#      17 DESCRIPTOR = _descriptor.FileDescriptor(
#      18   name='src/ray/protobuf/common.proto',
#      19   package='ray.rpc',
#      20   syntax='proto3',
#      21   serialized_options=b'\n\030io.ray.runtime.generated\370\001\001',
# ---> 22   create_key=_descriptor._internal_create_key,
#      23   serialized_pb=b'\n\x1dsrc/ray/protobuf/common.proto\x12\x07ray.rpc\"v\n\x07\x41\x64\x64ress\x12\x1b\n\traylet_id\x18\x01 \x01(\x0cR\x08rayletId\x12\x1d\n\nip_address\x18\x02 \x01(\tR\tipAddress\x12\x12\n\x04port\x18\x03 \x01(\x05R\x04port\x12\x1b\n\tworker_id\x18\x04 \x01(\x0cR\x08workerId\"z\n\x16JavaFunctionDescriptor\x12\x1d\n\nclass_name\x18\x01 \x01(\tR\tclassName\x12#\n\rfunction_name\x18\x02 \x01(\tR\x0c\x66unctionName\x12\x1c\n\tsignature\x18\x03 \x01(\tR\tsignature\"\xa4\x01\n\x18PythonFunctionDescriptor\x12\x1f\n\x0bmodule_name\x18\x01 \x01(\tR\nmoduleName\x12\x1d\n\nclass_name\x18\x02 \x01(\tR\tclassName\x12#\n\rfunction_name\x18\x03 \x01(\tR\x0c\x66unctionName\x12#\n\rfunction_hash\x18\x04 \x01(\tR\x0c\x66unctionHash\"<\n\x15\x43ppFunctionDescriptor\x12#\n\rfunction_name\x18\x01 \x01(\tR\x0c\x66unctionName\"\xc5\x02\n\x12\x46unctionDescriptor\x12[\n\x18java_function_descriptor\x18\x01 \x01(\x0b\x32\x1f.ray.rpc.JavaFunctionDescriptorH\x00R\x16javaFunctionDescriptor\x12\x61\n\x1apython_function_descriptor\x18\x02 \x01(\x0b\x32!.ray.rpc.PythonFunctionDescriptorH\x00R\x18pythonFunctionDescriptor\x12X\n\x17\x63pp_function_descriptor\x18\x03 \x01(\x0b\x32\x1e.ray.rpc.CppFunctionDescriptorH\x00R\x15\x63ppFunctionDescriptorB\x15\n\x13\x66unction_descriptor\"\x9f\x01\n\x10\x43oncurrencyGroup\x12\x12\n\x04name\x18\x01 \x01(\tR\x04name\x12\'\n\x0fmax_concurrency\x18\x02 \x01(\x05R\x0emaxConcurrency\x12N\n\x14\x66unction_descriptors\x18\x03 \x03(\x0b\x32\x1b.ray.rpc.FunctionDescriptorR\x13\x66unctionDescriptors\"\xae\x01\n\x0cRayException\x12-\n\x08language\x18\x01 \x01(\x0e\x32\x11.ray.rpc.LanguageR\x08language\x12\x31\n\x14serialized_exception\x18\x02 \x01(\x0cR\x13serializedException\x12<\n\x1a\x66ormatted_exception_string\x18\x03 \x01(\tR\x18\x66ormattedExceptionString\"\x91\x01\n\nRuntimeEnv\x12\x34\n\x16serialized_runtime_env\x18\x01 \x01(\tR\x14serializedRuntimeEnv\x12\x12\n\x04uris\x18\x02 \x03(\tR\x04uris\x12\x39\n\x19runtime_env_eager_install\x18\x03 \x01(\x08R\x16runtimeEnvEagerInstall\"\xbb\x0b\n\x08TaskSpec\x12%\n\x04type\x18\x01 \x01(\x0e\x32\x11.ray.rpc.TaskTypeR\x04type\x12\x12\n\x04name\x18\x02 \x01(\tR\x04name\x12-\n\x08language\x18\x03 \x01(\x0e\x32\x11.ray.rpc.LanguageR\x08language\x12L\n\x13\x66unction_descriptor\x18\x04 \x01(\x0b\x32\x1b.ray.rpc.FunctionDescriptorR\x12\x66unctionDescriptor\x12\x15\n\x06job_id\x18\x05 \x01(\x0cR\x05jobId\x12\x17\n\x07task_id\x18\x06 \x01(\x0cR\x06taskId\x12$\n\x0eparent_task_id\x18\x07 \x01(\x0cR\x0cparentTaskId\x12%\n\x0eparent_counter\x18\x08 \x01(\x04R\rparentCounter\x12\x1b\n\tcaller_id\x18\t \x01(\x0cR\x08\x63\x61llerId\x12\x37\n\x0e\x63\x61ller_address\x18\n \x01(\x0b\x32\x10.ray.rpc.AddressR\rcallerAddress\x12$\n\x04\x61rgs\x18\x0b \x03(\x0b\x32\x10.ray.rpc.TaskArgR\x04\x61rgs\x12\x1f\n\x0bnum_returns\x18\x0c \x01(\x04R\nnumReturns\x12W\n\x12required_resources\x18\r \x03(\x0b\x32(.ray.rpc.TaskSpec.RequiredResourcesEntryR\x11requiredResources\x12s\n\x1crequired_placement_resources\x18\x0e \x03(\x0b\x32\x31.ray.rpc.TaskSpec.RequiredPlacementResourcesEntryR\x1arequiredPlacementResources\x12W\n\x18\x61\x63tor_creation_task_spec\x18\x0f \x01(\x0b\x32\x1e.ray.rpc.ActorCreationTaskSpecR\x15\x61\x63torCreationTaskSpec\x12>\n\x0f\x61\x63tor_task_spec\x18\x10 \x01(\x0b\x32\x16.ray.rpc.ActorTaskSpecR\ractorTaskSpec\x12\x1f\n\x0bmax_retries\x18\x11 \x01(\x05R\nmaxRetries\x12,\n\x12placement_group_id\x18\x12 \x01(\x0cR\x10placementGroupId\x12?\n\x1cplacement_group_bundle_index\x18\x13 \x01(\x03R\x19placementGroupBundleIndex\x12L\n#placement_group_capture_child_tasks\x18\x14 \x01(\x08R\x1fplacementGroupCaptureChildTasks\x12%\n\x0eskip_execution\x18\x15 \x01(\x08R\rskipExecution\x12/\n\x13\x64\x65\x62ugger_breakpoint\x18\x16 \x01(\x0cR\x12\x64\x65\x62uggerBreakpoint\x12\x34\n\x0bruntime_env\x18\x17 \x01(\x0b\x32\x13.ray.rpc.RuntimeEnvR\nruntimeEnv\x12\x34\n\x16\x63oncurrency_group_name\x18\x18 \x01(\tR\x14\x63oncurrencyGroupName\x12)\n\x10retry_exceptions\x18\x19 \x01(\x ...
#      24 )
#      26 _LANGUAGE = _descriptor.EnumDescriptor(
#      27   name='Language',
#      28   full_name='ray.rpc.Language',
#    (...)
#      52   serialized_end=7823,
#      53 )
#      54 _sym_db.RegisterEnumDescriptor(_LANGUAGE)
#
# AttributeError: module 'google.protobuf.descriptor' has no attribute '_internal_create_key'
